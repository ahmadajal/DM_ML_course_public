# %% [markdown]
# # Titanic Classification
#
# <p><img style="float: left;margin:5px 20px 5px 1px" src="https://d6jf304m27oxw.cloudfront.net/titanic-conspiracy-the-ship-that-never-sank/titanic-in-southampton-dock.jpg"</p>
#
# <br>
# Who will die and who live? That is the question...
#
#
# Here will will load the a "clean" version of the data. You can see how the cleaning was done [here](https://www.kaggle.com/kernels/svzip/996088).
#
# And of course, behind every big disaster there is always an [intriguing conspiracy theory](https://theunredacted.com/titanic-conspiracy-the-ship-that-never-sank/) around it, as some people claim that it was not the Titanic that sank, but it's predecessor the Olympic, as part of an elaborate insurance scam.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)
# %matplotlib inline
#X = pd.read_csv('data/titanic_train-clean.csv')
X=pd.read_csv('https://raw.githubusercontent.com/ahmadajal/DM_ML_course_public/master/5.%20Classification/in-classExercise/data/titanic_train-clean.csv')
X.head()
# Out:
#    PassengerId   Age  Embarked     Fare  Pclass  Sex  Survived  Title  FSize
# 0            1  22.0         2   7.2500       3    1       0.0     12      1
# 1            2  38.0         0  71.2833       1    0       1.0     13      1
# 2            3  26.0         2   7.9250       3    0       1.0      9      0
# 3            4  35.0         2  53.1000       1    0       1.0     13      1
# 4            5  35.0         2   8.0500       3    1       0.0     12      0

# %%
# some housecleaning
y = X.Survived
X = X.drop(columns = 'PassengerId', axis=1)
# X = X.drop(columns = 'Survived', axis=1)

# %%
sns.pairplot(X, hue="Survived")
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
# 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X.drop('Survived', axis=1), y)

# %%
# training and prediction

model = LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=500)

# use the train to create the model
model.fit(----, -----)

# use the test to predict
y_pred = model.predict(---)

# %%
# evaluation

from sklearn.metrics import accuracy_score, confusion_matrix
print('Accuracy is',accuracy_score(---,---))
# Out:
# Accuracy is 0.7982062780269058

# %% [markdown]
# # Question
#
# You should have found an accuracy of approximately 80%? Is it good or bad?
#
# It all depends on the baserate. Baserate = $\frac{\text{most frequent class}}{\text{total observations}}$
#
# So, calculate the base rate!

# %%
# compute the base rate
# base rate = (most frequent class)/(total observations)

num_died = 
num_lived = 

print("#Lived = ", num_lived)
print("#Died = ", num_died)
print("Baserate = ", max(num_lived, num_died )/(num_died+ num_lived))
# Out:
# #Lived =  342
# #Died =  549
# Baserate =  0.6161616161616161
